# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계2 : 기본 모델링

# %% [markdown]
# ## 0.미션

# %% [markdown]
# * 데이터 전처리
#     * 가변수화, 데이터 분할, NaN 확인 및 조치, 스케일링 등 필요한 전처리 수행
# * 다양한 알고리즘으로 분류 모델 생성
#     * 최소 4개 이상의 알고리즘을 적용하여 모델링 수행
#     * 성능 비교
#     * 각 모델의 성능을 저장하는 별도 데이터 프레임을 만들고 비교
# * 옵션 : 다음 사항은 선택사항입니다. 시간이 허용하는 범위 내에서 수행하세요.
#     * 상위 N개 변수를 선정하여 모델링 및 성능 비교
#         * 모델링에 항상 모든 변수가 필요한 것은 아닙니다.
#         * 변수 중요도 상위 N개를 선정하여 모델링하고 타 모델과 성능을 비교하세요.
#         * 상위 N개를 선택하는 방법은, 변수를 하나씩 늘려가며 모델링 및 성능 검증을 수행하여 적절한 지점을 찾는 것입니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# ### (1) 라이브러리 불러오기

# %% [markdown]
# * 세부 요구사항
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#     - 필요하다고 판단되는 라이브러리를 추가하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 필요하다고 판단되는 라이브러리를 추가하세요.

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import *

# %% [markdown]
# * 함수 생성

# %%
# 변수의 특성 중요도 계산하기
def plot_feature_importance(importance, names, result_only = False, topn = 'all'):
    feature_importance = np.array(importance)
    feature_name = np.array(names)

    data={'feature_name':feature_name,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    #변수의 특성 중요도 순으로 정렬하기
    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    #변수의 특성 중요도 그래프로 그리기
    if result_only == False :
        plt.figure(figsize=(10,20))
        sns.barplot(x='feature_importance', y='feature_name', data = fi_df)

        plt.xlabel('importance')
        plt.ylabel('feature name')
        plt.grid()

    return fi_df

# %% [markdown]
# ### (2) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
# * 세부 요구사항
#     - 전체 데이터 'data01_train.csv' 를 불러와 'data' 이름으로 저장합니다.
#         - data에서 변수 subject는 삭제합니다.
#     - 데이터프레임에 대한 기본 정보를 확인합니다.( .head(), .shape 등)

# %% [markdown]
# #### 1) 데이터 로딩

# %%
#데이터 불러오기
data_path = "./data01_train.csv"
data = pd.read_csv(data_path)
data.drop('subject', axis=1, inplace=True)
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.965650         -0.929747  ...                        -0.487737
# 1         -0.987558         -0.937337  ...                        -0.237820
# 2         -0.995017         -0.942584  ...                        -0.535287
# 3         -0.347916          0.008288  ...                        -0.004012
# 4         -0.346372          0.584131  ...                        -0.157832
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.816696                    -0.042494
# 1                        -0.693515                    -0.062899
# 2                        -0.829311                     0.000265
# 3                        -0.408956                    -0.255125
# 4                        -0.563437                    -0.044344
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                             -0.044218                          0.307873
# 1                              0.388459                         -0.765014
# 2                             -0.525022                         -0.891875
# 3                              0.612804                          0.747381
# 4                             -0.845268                         -0.974650
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.072790             -0.601120
# 1                              0.771524              0.345205
# 2                              0.021528             -0.833564
# 3                             -0.072944             -0.695819
# 4                             -0.887846             -0.705029
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)            Activity
# 0              0.331298              0.165163            STANDING
# 1             -0.769186             -0.147944              LAYING
# 2              0.202434             -0.032755            STANDING
# 3              0.287154              0.111388             WALKING
# 4              0.264952              0.137758  WALKING_DOWNSTAIRS
#
# [5 rows x 562 columns]

# %%
#전체 데이터의 행,열 개수 확인
data.shape
# Out:
# (5881, 562)

# %%
#전체 데이터의 모든 변수 확인
data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-skewness()', 'fBodyBodyGyroJerkMag-kurtosis()',
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'Activity'],
#       dtype='object', length=562)

# %%
#전체 데이터의 수치형 변수 분포 확인
data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# 25%           -0.992774         -0.977680         -0.980127         -0.993602
# 50%           -0.943933         -0.844575         -0.856352         -0.948501
# 75%           -0.242130         -0.034499         -0.262690         -0.291138
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       5881.000000       5881.000000       5881.000000  ...
# mean          -0.525944         -0.605374         -0.465490  ...
# std            0.485115          0.413043          0.544995  ...
# min           -0.999419         -1.000000         -1.000000  ...
# 25%           -0.977865         -0.980112         -0.936067  ...
# 50%           -0.849266         -0.849896         -0.878729  ...
# 75%           -0.068857         -0.268539         -0.013690  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# count                      5881.000000                      5881.000000
# mean                          0.126955                        -0.305883
# std                           0.249176                         0.322808
# min                          -0.965725                        -0.979261
# 25%                          -0.021610                        -0.541969
# 50%                           0.133887                        -0.342923
# 75%                           0.288944                        -0.127371
# max                           0.946700                         0.989538
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      5881.000000                  5881.000000
# mean                         -0.623548                     0.008524
# std                           0.310371                     0.339730
# min                          -0.999765                    -0.976580
# 25%                          -0.845985                    -0.122361
# 50%                          -0.712677                     0.010278
# 75%                          -0.501158                     0.154985
# max                           0.956845                     1.000000
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           5881.000000                       5881.000000
# mean                              -0.001185                          0.009340
# std                                0.447197                          0.608190
# min                               -1.000000                         -1.000000
# 25%                               -0.294369                         -0.481718
# 50%                                0.005146                          0.011448
# 75%                                0.285030                          0.499857
# max                                1.000000                          0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           5881.000000           5881.000000
# mean                              -0.007099             -0.491501
# std                                0.476738              0.509069
# min                               -1.000000             -1.000000
# 25%                               -0.373345             -0.811397
# 50%                               -0.000847             -0.709441
# 75%                                0.356236             -0.511330
# max                                0.996078              0.977344
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)
# count           5881.000000           5881.000000
# mean               0.059299             -0.054594
# std                0.297340              0.278479
# min               -1.000000             -0.980143
# 25%               -0.018203             -0.141555
# 50%                0.182893              0.003951
# 75%                0.248435              0.111932
# max                0.478157              1.000000
#
# [8 rows x 561 columns]

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
# kde로 tBodyAcc-mean()-Y 분포 확인
var = 'tBodyAcc-mean()-Y'
plt.figure(figsize = (15,8))
sns.kdeplot(x=var, data = data, common_norm = False)
# Out:
# <AxesSubplot:xlabel='tBodyAcc-mean()-Y', ylabel='Density'>

# %%
# 전체 데이터의 이변량 분석 (corr)
# Activity 숫자로 변환
data['Activity_num'] = data['Activity'].map({'WALKING':0,
                                                 'WALKING_UPSTAIRS':1,
                                                 'WALKING_DOWNSTAIRS':2,
                                                 'LAYING':3,
                                                 'STANDING':4,
                                                 'SITTING':5})
data1 = data.drop(['Activity'],axis =1)
print(data1.dtypes)
# Out:
# tBodyAcc-mean()-X                       float64
# tBodyAcc-mean()-Y                       float64
# tBodyAcc-mean()-Z                       float64
# tBodyAcc-std()-X                        float64
# tBodyAcc-std()-Y                        float64
#                                          ...
# angle(tBodyGyroJerkMean,gravityMean)    float64
# angle(X,gravityMean)                    float64
# angle(Y,gravityMean)                    float64
# angle(Z,gravityMean)                    float64
# Activity_num                              int64
# Length: 562, dtype: object

# %%
# 전체 데이터의 이변량 분석 (corr)
data_corr = data1.corr()
data_corr
# Out:
#                                       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# tBodyAcc-mean()-X                              1.000000           0.203297
# tBodyAcc-mean()-Y                              0.203297           1.000000
# tBodyAcc-mean()-Z                             -0.266383          -0.145709
# tBodyAcc-std()-X                               0.012067          -0.049467
# tBodyAcc-std()-Y                              -0.018489          -0.052489
# ...                                                 ...                ...
# angle(tBodyGyroJerkMean,gravityMean)           0.030968           0.074955
# angle(X,gravityMean)                          -0.027010           0.000039
# angle(Y,gravityMean)                           0.028177           0.002376
# angle(Z,gravityMean)                           0.019025          -0.022329
# Activity_num                                   0.012249           0.065975
#
#                                       tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# tBodyAcc-mean()-X                             -0.266383          0.012067
# tBodyAcc-mean()-Y                             -0.145709         -0.049467
# tBodyAcc-mean()-Z                              1.000000         -0.024839
# tBodyAcc-std()-X                              -0.024839          1.000000
# tBodyAcc-std()-Y                              -0.017613          0.927809
# ...                                                 ...               ...
# angle(tBodyGyroJerkMean,gravityMean)          -0.035593         -0.024749
# angle(X,gravityMean)                           0.007045         -0.373500
# angle(Y,gravityMean)                          -0.017900          0.470834
# angle(Z,gravityMean)                          -0.019169          0.392843
# Activity_num                                   0.045042         -0.729811
#
#                                       tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# tBodyAcc-mean()-X                            -0.018489         -0.040405
# tBodyAcc-mean()-Y                            -0.052489         -0.058499
# tBodyAcc-mean()-Z                            -0.017613         -0.016924
# tBodyAcc-std()-X                              0.927809          0.851841
# tBodyAcc-std()-Y                              1.000000          0.893995
# ...                                                ...               ...
# angle(tBodyGyroJerkMean,gravityMean)         -0.015237         -0.004077
# angle(X,gravityMean)                         -0.380258         -0.346237
# angle(Y,gravityMean)                          0.521249          0.473572
# angle(Z,gravityMean)                          0.429141          0.480593
# Activity_num                                 -0.814393         -0.771374
#
#                                       tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# tBodyAcc-mean()-X                             0.018367         -0.019752
# tBodyAcc-mean()-Y                            -0.048703         -0.053018
# tBodyAcc-mean()-Z                            -0.023323         -0.015794
# tBodyAcc-std()-X                              0.998656          0.921154
# tBodyAcc-std()-Y                              0.923386          0.997320
# ...                                                ...               ...
# angle(tBodyGyroJerkMean,gravityMean)         -0.025205         -0.013152
# angle(X,gravityMean)                         -0.370024         -0.376665
# angle(Y,gravityMean)                          0.466287          0.522401
# angle(Z,gravityMean)                          0.389196          0.427486
# Activity_num                                 -0.725476         -0.814512
#
#                                       tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# tBodyAcc-mean()-X                            -0.043303          0.048725  ...
# tBodyAcc-mean()-Y                            -0.058559         -0.038544  ...
# tBodyAcc-mean()-Z                            -0.012575         -0.040397  ...
# tBodyAcc-std()-X                              0.846308          0.981190  ...
# tBodyAcc-std()-Y                              0.892843          0.916853  ...
# ...                                                ...               ...  ...
# angle(tBodyGyroJerkMean,gravityMean)         -0.004784         -0.028239  ...
# angle(X,gravityMean)                         -0.348279         -0.385300  ...
# angle(Y,gravityMean)                          0.474880          0.478832  ...
# angle(Z,gravityMean)                          0.477848          0.401217  ...
# Activity_num                                 -0.775233         -0.730359  ...
#
#                                       fBodyBodyGyroJerkMag-skewness()  \
# tBodyAcc-mean()-X                                           -0.012101
# tBodyAcc-mean()-Y                                           -0.003101
# tBodyAcc-mean()-Z                                            0.018155
# tBodyAcc-std()-X                                             0.151555
# tBodyAcc-std()-Y                                             0.209119
# ...                                                               ...
# angle(tBodyGyroJerkMean,gravityMean)                        -0.018015
# angle(X,gravityMean)                                        -0.088810
# angle(Y,gravityMean)                                         0.092383
# angle(Z,gravityMean)                                         0.056005
# Activity_num                                                -0.251986
#
#                                       fBodyBodyGyroJerkMag-kurtosis()  \
# tBodyAcc-mean()-X                                           -0.011490
# tBodyAcc-mean()-Y                                           -0.003467
# tBodyAcc-mean()-Z                                            0.018234
# tBodyAcc-std()-X                                             0.116425
# tBodyAcc-std()-Y                                             0.177232
# ...                                                               ...
# angle(tBodyGyroJerkMean,gravityMean)                        -0.015179
# angle(X,gravityMean)                                        -0.080113
# angle(Y,gravityMean)                                         0.080726
# angle(Z,gravityMean)                                         0.049690
# Activity_num                                                -0.228656
#
#                                       angle(tBodyAccMean,gravity)  \
# tBodyAcc-mean()-X                                       -0.567455
# tBodyAcc-mean()-Y                                        0.076995
# tBodyAcc-mean()-Z                                        0.056806
# tBodyAcc-std()-X                                        -0.043069
# tBodyAcc-std()-Y                                        -0.027671
# ...                                                           ...
# angle(tBodyGyroJerkMean,gravityMean)                    -0.027075
# angle(X,gravityMean)                                     0.012382
# angle(Y,gravityMean)                                    -0.000955
# angle(Z,gravityMean)                                    -0.004422
# Activity_num                                            -0.009933
#
#                                       angle(tBodyAccJerkMean),gravityMean)  \
# tBodyAcc-mean()-X                                                 0.019251
# tBodyAcc-mean()-Y                                                -0.013001
# tBodyAcc-mean()-Z                                                -0.036749
# tBodyAcc-std()-X                                                 -0.032145
# tBodyAcc-std()-Y                                                 -0.022181
# ...                                                                    ...
# angle(tBodyGyroJerkMean,gravityMean)                              0.029856
# angle(X,gravityMean)                                              0.020700
# angle(Y,gravityMean)                                             -0.013508
# angle(Z,gravityMean)                                             -0.014844
# Activity_num                                                      0.018873
#
#                                       angle(tBodyGyroMean,gravityMean)  \
# tBodyAcc-mean()-X                                             0.034065
# tBodyAcc-mean()-Y                                             0.019670
# tBodyAcc-mean()-Z                                            -0.054069
# tBodyAcc-std()-X                                              0.016542
# tBodyAcc-std()-Y                                             -0.012927
# ...                                                                ...
# angle(tBodyGyroJerkMean,gravityMean)                         -0.113677
# angle(X,gravityMean)                                         -0.001992
# angle(Y,gravityMean)                                         -0.013863
# angle(Z,gravityMean)                                         -0.021702
# Activity_num                                                  0.027654
#
#                                       angle(tBodyGyroJerkMean,gravityMean)  \
# tBodyAcc-mean()-X                                                 0.030968
# tBodyAcc-mean()-Y                                                 0.074955
# tBodyAcc-mean()-Z                                                -0.035593
# tBodyAcc-std()-X                                                 -0.024749
# tBodyAcc-std()-Y                                                 -0.015237
# ...                                                                    ...
# angle(tBodyGyroJerkMean,gravityMean)                              1.000000
# angle(X,gravityMean)                                              0.012598
# angle(Y,gravityMean)                                              0.005132
# angle(Z,gravityMean)                                              0.001242
# Activity_num                                                     -0.005633
#
#                                       angle(X,gravityMean)  \
# tBodyAcc-mean()-X                                -0.027010
# tBodyAcc-mean()-Y                                 0.000039
# tBodyAcc-mean()-Z                                 0.007045
# tBodyAcc-std()-X                                 -0.373500
# tBodyAcc-std()-Y                                 -0.380258
# ...                                                    ...
# angle(tBodyGyroJerkMean,gravityMean)              0.012598
# angle(X,gravityMean)                              1.000000
# angle(Y,gravityMean)                             -0.783107
# angle(Z,gravityMean)                             -0.639201
# Activity_num                                      0.105635
#
#                                       angle(Y,gravityMean)  \
# tBodyAcc-mean()-X                                 0.028177
# tBodyAcc-mean()-Y                                 0.002376
# tBodyAcc-mean()-Z                                -0.017900
# tBodyAcc-std()-X                                  0.470834
# tBodyAcc-std()-Y                                  0.521249
# ...                                                    ...
# angle(tBodyGyroJerkMean,gravityMean)              0.005132
# angle(X,gravityMean)                             -0.783107
# angle(Y,gravityMean)                              1.000000
# angle(Z,gravityMean)                              0.590883
# Activity_num                                     -0.312724
#
#                                       angle(Z,gravityMean)  Activity_num
# tBodyAcc-mean()-X                                 0.019025      0.012249
# tBodyAcc-mean()-Y                                -0.022329      0.065975
# tBodyAcc-mean()-Z                                -0.019169      0.045042
# tBodyAcc-std()-X                                  0.392843     -0.729811
# tBodyAcc-std()-Y                                  0.429141     -0.814393
# ...                                                    ...           ...
# angle(tBodyGyroJerkMean,gravityMean)              0.001242     -0.005633
# angle(X,gravityMean)                             -0.639201      0.105635
# angle(Y,gravityMean)                              0.590883     -0.312724
# angle(Z,gravityMean)                              1.000000     -0.265984
# Activity_num                                     -0.265984      1.000000
#
# [562 rows x 562 columns]

# %%
# 이변량 시각화 하기  (변수를 줄여서 해보는 것도 의미 있겠죠?)
plt.figure(figsize = (15,15))
ax = sns.heatmap(data_corr)

# %% [markdown]
# ## **2. 데이터 전처리**
#
# * 가변수화, 데이터 분할, NaN 확인 및 조치, 스케일링 등 필요한 전처리를 수행한다.

# %% [markdown]
# ### (1) 데이터 분할1 : x, y

# %% [markdown]
# * 세부 요구사항
#     - x, y로 분할합니다.

# %%
# 데이터 분할을 위한 전처리
target = 'Activity'
x = data.drop(target, axis = 1)
x = data.drop('Activity_num', axis = 1)
y = data.loc[:, target]

# %%
x
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288508          -0.009196          -0.103362
# 1              0.265757          -0.016576          -0.098163
# 2              0.278709          -0.014511          -0.108717
# 3              0.289795          -0.035536          -0.150354
# 4              0.394807           0.034098           0.091229
# ...                 ...                ...                ...
# 5876           0.277194          -0.012389          -0.131974
# 5877           0.191568           0.013328          -0.105174
# 5878           0.267981          -0.018348          -0.107440
# 5879           0.212787          -0.048130          -0.121001
# 5880           0.283815          -0.040658          -0.138018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.988986         -0.962797         -0.967422         -0.989000
# 1            -0.989551         -0.994636         -0.987435         -0.990189
# 2            -0.997720         -0.981088         -0.994008         -0.997934
# 3            -0.231727         -0.006412         -0.338117         -0.273557
# 4             0.088489         -0.106636         -0.388502         -0.010469
# ...                ...               ...               ...               ...
# 5876         -0.994046         -0.940578         -0.917337         -0.994261
# 5877         -0.126969         -0.121729         -0.327480         -0.192523
# 5878         -0.991303         -0.989881         -0.990313         -0.992386
# 5879         -0.041373          0.052449         -0.585361         -0.100714
# 5880         -0.992662         -0.747190         -0.920248         -0.993410
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.962596         -0.965650         -0.929747  ...
# 1            -0.993870         -0.987558         -0.937337  ...
# 2            -0.982187         -0.995017         -0.942584  ...
# 3             0.014245         -0.347916          0.008288  ...
# 4            -0.109680         -0.346372          0.584131  ...
# ...                ...               ...               ...  ...
# 5876         -0.932830         -0.908088         -0.936219  ...
# 5877         -0.109923         -0.295286          0.078644  ...
# 5878         -0.988852         -0.991237         -0.936099  ...
# 5879          0.023353         -0.554707          0.219814  ...
# 5880         -0.768055         -0.924587         -0.935871  ...
#
#       fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                           -0.487737                        -0.816696
# 1                           -0.237820                        -0.693515
# 2                           -0.535287                        -0.829311
# 3                           -0.004012                        -0.408956
# 4                           -0.157832                        -0.563437
# ...                               ...                              ...
# 5876                        -0.305772                        -0.690363
# 5877                        -0.622617                        -0.879215
# 5878                        -0.597610                        -0.886851
# 5879                         0.196921                        -0.053556
# 5880                        -0.379740                        -0.696584
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                       -0.042494                             -0.044218
# 1                       -0.062899                              0.388459
# 2                        0.000265                             -0.525022
# 3                       -0.255125                              0.612804
# 4                       -0.044344                             -0.845268
# ...                           ...                                   ...
# 5876                    -0.034888                             -0.261437
# 5877                     0.721718                              0.623151
# 5878                     0.060173                              0.228739
# 5879                     0.260880                              0.551742
# 5880                     0.107690                              0.122242
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                             0.307873                              0.072790
# 1                            -0.765014                              0.771524
# 2                            -0.891875                              0.021528
# 3                             0.747381                             -0.072944
# 4                            -0.974650                             -0.887846
# ...                                ...                                   ...
# 5876                         -0.391477                             -0.877612
# 5877                          0.866858                             -0.445660
# 5878                          0.684400                             -0.216665
# 5879                         -0.943773                             -0.862899
# 5880                         -0.077226                             -0.078091
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0                -0.601120              0.331298              0.165163
# 1                 0.345205             -0.769186             -0.147944
# 2                -0.833564              0.202434             -0.032755
# 3                -0.695819              0.287154              0.111388
# 4                -0.705029              0.264952              0.137758
# ...                    ...                   ...                   ...
# 5876             -0.912365              0.114009              0.080146
# 5877             -0.690278              0.303194             -0.044188
# 5878              0.620363             -0.437247             -0.571840
# 5879             -0.718009              0.292856              0.024920
# 5880             -0.740244              0.008346             -0.146143
#
#                 Activity
# 0               STANDING
# 1                 LAYING
# 2               STANDING
# 3                WALKING
# 4     WALKING_DOWNSTAIRS
# ...                  ...
# 5876             SITTING
# 5877    WALKING_UPSTAIRS
# 5878              LAYING
# 5879    WALKING_UPSTAIRS
# 5880             SITTING
#
# [5881 rows x 562 columns]

# %% [markdown]
# ### (2) 스케일링(필요시)

# %% [markdown]
# * 세부 요구사항
#     - 스케일링을 필요로 하는 알고리즘 사용을 위해서 코드 수행
#     - min-max 방식 혹은 standard 방식 중 한가지 사용.

# %% [markdown]
# ### (3) 데이터분할2 : train, validation

# %% [markdown]
# * 세부 요구사항
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .3)

# %% [markdown]
# ## **3. 기본 모델링**

# %% [markdown]
# * 세부 요구사항
#     - 최소 4개 이상의 알고리즘을 적용하여 모델링을 수행한다.
#     - 각 알고리즘별로 전체 변수로 모델링, 상위 N개 변수를 선택하여 모델링을 수행하고 성능 비교를 한다.
#     - (옵션) 알고리즘 중 1~2개에 대해서, 변수 중요도 상위 N개를 선정하여 모델링하고 타 모델과 성능을 비교.
#         * 상위 N개를 선택하는 방법은, 변수를 하나씩 늘려가며 모델링 및 성능 검증을 수행하여 적절한 지점을 찾는 것이다.

# %% [markdown]
# ### (1) 알고리즘1 :

# %%
#생성
model = RandomForestClassifier()

#학습
model.fit(x_train, y_train)
pred = model.predict(x_val)

#평가
print('accuracy :',accuracy_score(y_val, pred))
print('='*60)
print(confusion_matrix(y_val, pred))
print('='*60)
print(classification_report(y_val, pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nb/vw8gj0_j4bl5c7lm4zvs8kyh0000gn/T/ipykernel_96068/1030873394.py in <module>
#       3
#       4 #학습
# ----> 5 model.fit(x_train, y_train)
#       6 pred = model.predict(x_val)
#       7
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     325         if issparse(y):
#     326             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 327         X, y = self._validate_data(
#     328             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     329         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     962         raise ValueError("y cannot be None")
#     963
# --> 964     X = check_array(
#     965         X,
#     966         accept_sparse=accept_sparse,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#
# ValueError: could not convert string to float: 'WALKING'

# %%
# 변수 중요도 추출
r1 = plot_feature_importance(model.feature_importances_, list(x_train), False)
r1
# Out:
#                            feature_name  feature_importance
# 0                          Activity_num            0.091955
# 1                  tGravityAcc-mean()-Y            0.030732
# 2                tGravityAcc-energy()-X            0.027377
# 3                  tGravityAcc-mean()-X            0.026737
# 4                  angle(X,gravityMean)            0.026275
# ..                                  ...                 ...
# 557      fBodyAcc-bandsEnergy()-33,40.1            0.000063
# 558  fBodyAccJerk-bandsEnergy()-33,40.2            0.000055
# 559                   fBodyGyro-min()-Y            0.000054
# 560      fBodyAcc-bandsEnergy()-25,32.1            0.000052
# 561      fBodyAcc-bandsEnergy()-57,64.2            0.000042
#
# [562 rows x 2 columns]

# %%
r1.head(11)
# Out:
#               feature_name  feature_importance
# 0             Activity_num            0.091955
# 1     tGravityAcc-mean()-Y            0.030732
# 2   tGravityAcc-energy()-X            0.027377
# 3     tGravityAcc-mean()-X            0.026737
# 4     angle(X,gravityMean)            0.026275
# 5     angle(Y,gravityMean)            0.026160
# 6      tGravityAcc-min()-X            0.023247
# 7      tGravityAcc-max()-X            0.022415
# 8   tGravityAcc-energy()-Y            0.020474
# 9      tGravityAcc-max()-Y            0.016311
# 10     tGravityAcc-min()-Y            0.015518

# %%
x1 = x[['tGravityAcc-mean()-Y','tGravityAcc-energy()-X','tGravityAcc-mean()-X','angle(X,gravityMean)','angle(Y,gravityMean)','tGravityAcc-min()-X','tGravityAcc-max()-X','tGravityAcc-energy()-Y','tGravityAcc-max()-Y','tGravityAcc-min()-Y']]
x_train, x_val, y_train, y_val = train_test_split(x1, y, test_size = .3)

#생성
model = RandomForestClassifier()

#학습
model.fit(x_train, y_train)
pred = model.predict(x_val)

#평가
print('accuracy :',accuracy_score(y_val, pred))
print('='*60)
print(confusion_matrix(y_val, pred))
print('='*60)
print(classification_report(y_val, pred))
# Out:
# accuracy : 0.8940509915014164
# ============================================================
# [[356   0   0   0   0   0]
#  [  0 293   9   2   1   0]
#  [  0   8 280  26   8  12]
#  [  0   2   9 244  24  12]
#  [  0   3   1  18 196  17]
#  [  0   2   1  11  21 209]]
# ============================================================
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       356
#            SITTING       0.95      0.96      0.96       305
#           STANDING       0.93      0.84      0.88       334
#            WALKING       0.81      0.84      0.82       291
# WALKING_DOWNSTAIRS       0.78      0.83      0.81       235
#   WALKING_UPSTAIRS       0.84      0.86      0.85       244
#
#           accuracy                           0.89      1765
#          macro avg       0.89      0.89      0.89      1765
#       weighted avg       0.90      0.89      0.89      1765

# %% [markdown]
# ### (2) 알고리즘2 :

# %% [markdown]
# ### (3) 알고리즘3 :

# %% [markdown]
# ### (4) 알고리즘4 :
